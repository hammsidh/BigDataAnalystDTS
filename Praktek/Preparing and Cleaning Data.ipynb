# %% [markdown]
# # Preparing and Cleaning Data

# %% [markdown]
# *Oleh: Rosihan Ari Yuana, S. Si, M. Kom*

# %% [markdown]
# Diberikan dataset daftar transfer pemain bola termahal dunia dari musim 2000-2001 hingga 2018-2019.

# %% [markdown]
# ## Preparing Data

# %% [markdown]
# ### Importing Data

# %%
import pandas as pd
namaFile = "football.csv"
data = pd.read_csv(namaFile)
data.head()
# Out:
#                 Name        Position  Age     Team_from     League_from  \
# 0          Luís Figo    Right Winger   27  FC Barcelona          LaLiga
# 1      Hernán Crespo  Centre-Forward   25         Parma         Serie A
# 2      Marc Overmars     Left Winger   27       Arsenal  Premier League
# 3  Gabriel Batistuta  Centre-Forward   31    Fiorentina         Serie A
# 4     Nicolas Anelka  Centre-Forward   21   Real Madrid          LaLiga
#
#         Team_to League_to     Season  Market_value  Transfer_fee
# 0   Real Madrid    LaLiga  2000-2001           NaN    60000000.0
# 1         Lazio   Serie A  2000-2001           NaN           NaN
# 2  FC Barcelona    LaLiga  2000-2001           NaN           NaN
# 3       AS Roma   Serie A  2000-2001           NaN        3600.0
# 4      Paris SG   Ligue 1  2000-2001           NaN    34500000.0

# %% [markdown]
# ### Selecting Data

# %% [markdown]
# Data hasil import menggunakan Pandas seperti di atas bertipe DataFrame. DataFrame merupakan tipe data dinamis yang tersusun atas baris dan kolom (seperti tabel). Angka 0, 1 dst yang ada di sebelah kiri merupakan indeks baris. Sedangkan bagian paling atas memiliki nama kolom (column names).

# %%
# mengakses data pada baris index tertentu
data
# Out:
#                          Name            Position  Age        Team_from  \
# 0                   Luís Figo        Right Winger   27     FC Barcelona
# 1               Hernán Crespo      Centre-Forward   25            Parma
# 2               Marc Overmars         Left Winger   27          Arsenal
# 3           Gabriel Batistuta      Centre-Forward   31       Fiorentina
# 4              Nicolas Anelka      Centre-Forward   21      Real Madrid
# 5               Rio Ferdinand         Centre-Back   22         West Ham
# 6            Flávio Conceicao    Central Midfield   26   Dep. La Coruña
# 7              Savo Milosevic      Centre-Forward   26    Real Zaragoza
# 8             David Trézéguet      Centre-Forward   22           Monaco
# 9               Claudio López      Centre-Forward   25      Valencia CF
# 10    Jimmy Floyd Hasselbaink      Centre-Forward   28  Atlético Madrid
# 11               Gerard López    Central Midfield   21      Valencia CF
# 12                      Lucas      Centre-Forward   21      Atlético-PR
# 13                Pablo Aimar  Attacking Midfield   21      River Plate
# 14              Wálter Samuel         Centre-Back   22     Boca Juniors
# 15              Shabani Nonda      Centre-Forward   23    Stade Rennais
# 16               Robbie Keane      Centre-Forward   19    Coventry City
# 17                  José Mari      Centre-Forward   21  Atlético Madrid
# 18            Jonathan Zebina         Centre-Back   21  Cagliari Calcio
# 19                    Émerson  Defensive Midfield   24  Bay. Leverkusen
# 20             Tore André Flo      Centre-Forward   27          Chelsea
# 21              Sergiy Rebrov      Second Striker   26      Dynamo Kyiv
# 22             Angelo Peruzzi          Goalkeeper   30            Inter
# 23              Diego Tristán      Centre-Forward   24     RCD Mallorca
# 24            Sylvain Wiltord      Second Striker   26      G. Bordeaux
# 25           Fernando Redondo  Defensive Midfield   31      Real Madrid
# 26                     Jardel      Centre-Forward   26         FC Porto
# 27                 Nuno Gomes      Centre-Forward   24          Benfica
# 28           Sérgio Conceição        Right Winger   25            Lazio
# 29                    Alfonso      Centre-Forward   27       Real Betis
# ...                       ...                 ...  ...              ...
# 4671           Gonzalo Castro    Central Midfield   31    Bor. Dortmund
# 4672              Sergi Gómez         Centre-Back   26    Celta de Vigo
# 4673              Adam Masina           Left-Back   24          Bologna
# 4674       Christophe Hérelle         Centre-Back   25           Troyes
# 4675            Firmin Mubele      Centre-Forward   24    Stade Rennais
# 4676      Florent Hadergjonaj          Right-Back   23    FC Ingolstadt
# 4677       Nemanja Maksimovic    Central Midfield   23      Valencia CF
# 4678              Juan Iturbe        Right Winger   25          AS Roma
# 4679                  Sidcley           Left-Back   25      Atlético-PR
# 4680                 Fabrício      Centre-Forward   28     Portimonense
# 4681             Johan Mojica           Left-Back   25   Rayo Vallecano
# 4682                   Petros    Central Midfield   29        São Paulo
# 4683         Christian Kouamé      Centre-Forward   20       Cittadella
# 4684         Luca Waldschmidt      Centre-Forward   22     Hamburger SV
# 4685             Marc Muniesa         Centre-Back   26       Stoke City
# 4686          Pietro Iemmello      Centre-Forward   26         Sassuolo
# 4687             Felipe Vizeu      Centre-Forward   21         Flamengo
# 4688         Marco Tumminello      Centre-Forward   19          AS Roma
# 4689             Jens Odgaard      Centre-Forward   19            Inter
# 4690            Marco Carraro  Defensive Midfield   20            Inter
# 4691           Jonathan Ikoné  Attacking Midfield   20         Paris SG
# 4692      Giangiacomo Magnani         Centre-Back   22         Juventus
# 4693      Giangiacomo Magnani         Centre-Back   22          Perugia
# 4694             Evan N'Dicka         Centre-Back   18       AJ Auxerre
# 4695            Jasmin Kurtic  Attacking Midfield   29         Atalanta
# 4696                Tchê Tchê    Central Midfield   25        Palmeiras
# 4697            Silvan Widmer          Right-Back   25   Udinese Calcio
# 4698               Yuya Osako      Second Striker   28       1. FC Köln
# 4699             Kyle Bartley         Centre-Back   27          Swansea
# 4700        Rosihan Ari Yuana       "Goal Keeper"   40       "Bolon FC"
#
#           League_from            Team_to            League_to        Season  \
# 0              LaLiga        Real Madrid               LaLiga     2000-2001
# 1             Serie A              Lazio              Serie A     2000-2001
# 2      Premier League       FC Barcelona               LaLiga     2000-2001
# 3             Serie A            AS Roma              Serie A     2000-2001
# 4              LaLiga           Paris SG              Ligue 1     2000-2001
# 5      Premier League              Leeds       Premier League     2000-2001
# 6              LaLiga        Real Madrid               LaLiga     2000-2001
# 7              LaLiga              Parma              Serie A     2000-2001
# 8             Ligue 1           Juventus              Serie A     2000-2001
# 9              LaLiga              Lazio              Serie A     2000-2001
# 10            LaLiga2            Chelsea       Premier League     2000-2001
# 11             LaLiga       FC Barcelona               LaLiga     2000-2001
# 12             Brazil      Stade Rennais              Ligue 1     2000-2001
# 13          Argentina        Valencia CF               LaLiga     2000-2001
# 14          Argentina            AS Roma              Serie A     2000-2001
# 15            Ligue 1             Monaco              Ligue 1     2000-2001
# 16     Premier League              Inter              Serie A     2000-2001
# 17            LaLiga2           AC Milan              Serie A     2000-2001
# 18            Serie B            AS Roma              Serie A     2000-2001
# 19       1.Bundesliga            AS Roma              Serie A     2000-2001
# 20     Premier League            Rangers             Scotland     2000-2001
# 21       Premier Liga              Spurs       Premier League     2000-2001
# 22            Serie A              Lazio              Serie A     2000-2001
# 23             LaLiga     Dep. La Coruña               LaLiga     2000-2001
# 24            Ligue 1            Arsenal       Premier League     2000-2001
# 25             LaLiga           AC Milan              Serie A     2000-2001
# 26           Liga NOS        Galatasaray            Süper Lig     2000-2001
# 27           Liga NOS         Fiorentina              Serie A     2000-2001
# 28            Serie A              Parma              Serie A     2000-2001
# 29            LaLiga2       FC Barcelona               LaLiga     2000-2001
# ...               ...                ...                  ...           ...
# 4671     1.Bundesliga      VfB Stuttgart         1.Bundesliga     2018-2019
# 4672           LaLiga         Sevilla FC               LaLiga     2018-2019
# 4673          Serie A            Watford       Premier League     2018-2019
# 4674          Ligue 2           OGC Nice              Ligue 1     2018-2019
# 4675          Ligue 1           Toulouse              Ligue 1     2018-2019
# 4676     2.Bundesliga       Huddersfield       Premier League     2018-2019
# 4677           LaLiga          Getafe CF               LaLiga     2018-2019
# 4678          Serie A       Club Tijuana     Liga MX Apertura     2018-2019
# 4679          Série A        Dynamo Kyiv         Premier Liga     2018-2019
# 4680         Liga NOS         Urawa Reds            J1 League     2018-2019
# 4681           LaLiga          Girona FC               LaLiga     2018-2019
# 4682          Série A               Nasr  Professional League     2018-2019
# 4683          Serie B              Genoa              Serie A     2018-2019
# 4684     2.Bundesliga        SC Freiburg         1.Bundesliga     2018-2019
# 4685     Championship          Girona FC               LaLiga     2018-2019
# 4686          Serie A          Benevento              Serie B     2018-2019
# 4687          Série A     Udinese Calcio              Serie A     2018-2019
# 4688          Serie A           Atalanta              Serie A     2018-2019
# 4689          Serie A           Sassuolo              Serie A     2018-2019
# 4690          Serie A           Atalanta              Serie A     2018-2019
# 4691          Ligue 1         LOSC Lille              Ligue 1     2018-2019
# 4692          Serie A           Sassuolo              Serie A     2018-2019
# 4693          Serie B           Juventus              Serie A     2018-2019
# 4694          Ligue 2       E. Frankfurt         1.Bundesliga     2018-2019
# 4695          Serie A               SPAL              Serie A     2018-2019
# 4696          Série A        Dynamo Kyiv         Premier Liga     2018-2019
# 4697          Serie A           FC Basel         Super League     2018-2019
# 4698     2.Bundesliga      Werder Bremen         1.Bundesliga     2018-2019
# 4699     Championship          West Brom         Championship     2018-2019
# 4700   "Bolon League"   "Ajax Amsterdam"         "Bundesliga"   "2018-2019"
#
#       Market_value  Transfer_fee
# 0              NaN    60000000.0
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN        3600.0
# 4              NaN    34500000.0
# 5              NaN    26000000.0
# 6              NaN    25000000.0
# 7              NaN    25000000.0
# 8              NaN    23240000.0
# 9              NaN    23000000.0
# 10             NaN    22500000.0
# 11             NaN    21600000.0
# 12             NaN    21300000.0
# 13             NaN    21250000.0
# 14             NaN    20800000.0
# 15             NaN    20000000.0
# 16             NaN    19500000.0
# 17             NaN    19000000.0
# 18             NaN    18400000.0
# 19             NaN    18000000.0
# 20             NaN    18000000.0
# 21             NaN    18000000.0
# 22             NaN    17900000.0
# 23             NaN    17750000.0
# 24             NaN    17500000.0
# 25             NaN    17500000.0
# 26             NaN    17050000.0
# 27             NaN    17000000.0
# 28             NaN    17000000.0
# 29             NaN    16500000.0
# ...            ...           ...
# 4671     8000000.0     5000000.0
# 4672     8000000.0     5000000.0
# 4673     7000000.0     5000000.0
# 4674     6000000.0     5000000.0
# 4675     6000000.0     5000000.0
# 4676     5000000.0     5000000.0
# 4677     5000000.0     5000000.0
# 4678     4000000.0     5000000.0
# 4679     4000000.0     5000000.0
# 4680     4000000.0     5000000.0
# 4681     4000000.0     5000000.0
# 4682     3000000.0     5000000.0
# 4683     2800000.0     5000000.0
# 4684     2500000.0     5000000.0
# 4685     2500000.0     5000000.0
# 4686     2000000.0     5000000.0
# 4687     1500000.0     5000000.0
# 4688     1000000.0     5000000.0
# 4689      800000.0     5000000.0
# 4690      800000.0     5000000.0
# 4691      700000.0     5000000.0
# 4692      600000.0     5000000.0
# 4693      600000.0     5000000.0
# 4694      400000.0     5000000.0
# 4695     5000000.0     4800000.0
# 4696     3000000.0     4800000.0
# 4697     8500000.0     4500000.0
# 4698     4500000.0     4500000.0
# 4699     3500000.0     4500000.0
# 4700           NaN         100.0
#
# [4701 rows x 10 columns]

# %%
# mengakses 5 data pertama pada kolom tertentu
data['Name'][:5]
# Out:
# 0            Luís Figo
# 1        Hernán Crespo
# 2        Marc Overmars
# 3    Gabriel Batistuta
# 4       Nicolas Anelka
# Name: Name, dtype: object

# %%
# memilih data dari beberapa kolom
data = data.filter(items=['Name', 'Position', 'Age', 'Transfer_fee'])
data.head()
# Out:
#                 Name        Position  Age  Transfer_fee
# 0          Luís Figo    Right Winger   27    60000000.0
# 1      Hernán Crespo  Centre-Forward   25           NaN
# 2      Marc Overmars     Left Winger   27           NaN
# 3  Gabriel Batistuta  Centre-Forward   31        3600.0
# 4     Nicolas Anelka  Centre-Forward   21    34500000.0

# %% [markdown]
# ### Combining Data

# %%
ListUmur = []
for umur in data['Age']:
    if umur > 30:
        ListUmur.append('Old')
    else:
        ListUmur.append('Young')
data['Age Status'] = ListUmur
data.head()
# Out:
#                 Name        Position  Age  Transfer_fee Age Status
# 0          Luís Figo    Right Winger   27    60000000.0      Young
# 1      Hernán Crespo  Centre-Forward   25           NaN      Young
# 2      Marc Overmars     Left Winger   27           NaN      Young
# 3  Gabriel Batistuta  Centre-Forward   31        3600.0        Old
# 4     Nicolas Anelka  Centre-Forward   21    34500000.0      Young

# %% [markdown]
# ### Transforming Data

# %%
# sebelum transformasi

import matplotlib.pyplot as plt
plt.hist(data['Age'], 20)
plt.show()

# %%
# transforming data

from sklearn import preprocessing
import numpy as np

age_array = np.array(data['Age'])
normalized_age = preprocessing.normalize([age_array])
data['Norm Age'] = normalized_age[0]
data.head()
# Out:
#                 Name        Position  Age  Transfer_fee Age Status  Norm Age
# 0          Luís Figo    Right Winger   27    60000000.0      Young  0.016036
# 1      Hernán Crespo  Centre-Forward   25           NaN      Young  0.014848
# 2      Marc Overmars     Left Winger   27           NaN      Young  0.016036
# 3  Gabriel Batistuta  Centre-Forward   31        3600.0        Old  0.018412
# 4     Nicolas Anelka  Centre-Forward   21    34500000.0      Young  0.012473

# %%
# setelah transformasi

import matplotlib.pyplot as plt
plt.hist(data['Norm Age'], 20)
plt.show()

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Finding NaN Value (Missing Value)

# %%
data[data['Transfer_fee'].isnull()]
# Out:
#                   Name            Position  Age  Transfer_fee Age Status  \
# 1        Hernán Crespo      Centre-Forward   25           NaN      Young
# 2        Marc Overmars         Left Winger   27           NaN      Young
# 4537  Marcelo Saracchi           Left-Back   20           NaN      Young
# 4539       Dusan Tadic  Attacking Midfield   29           NaN      Young
#
#       Norm Age
# 1     0.014848
# 2     0.016036
# 4537  0.011879
# 4539  0.017224

# %% [markdown]
# ### Handling NaN Value (Missing Value)

# %%
# menghapus baris yang mengandung null
data1 = data.dropna(axis=0, how='any')
# cek data null
data1[data1['Transfer_fee'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Position, Age, Transfer_fee, Age Status, Norm Age]
# Index: []

# %%
# mengganti data null pada 'Transfer_fee' dengan rata2nya
data2 = data.fillna(data['Transfer_fee'].mean())
# cek data null
data2[data2['Transfer_fee'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Position, Age, Transfer_fee, Age Status, Norm Age]
# Index: []

# %%
# cek data pada baris ke 4539 yang tadinya null pada kolom Transfer_fee
data2.loc[4539]
# Out:
# Name                   Dusan Tadic
# Position        Attacking Midfield
# Age                             29
# Transfer_fee           9.40624e+06
# Age Status                   Young
# Norm Age                 0.0172241
# Name: 4539, dtype: object

# %% [markdown]
# ### Identifying Outliers (Pencilan)

# %%
# mengidentifikasi outliers via scatter plot

import matplotlib.pyplot as plt
plt.scatter(data['Age'], data['Transfer_fee'])
plt.xlabel('Age')
plt.ylabel('Transfer Fee')
plt.xlim(-1, 50)
plt.ylim(-1e7, 2.5e8)
plt.show()

# %% [markdown]
# ### Handling Outliers

# %%
# memilih data yang tidak mengandung outliers
import numpy as np

meanTransferFee = data['Transfer_fee'].mean()
stdTransferFee = data['Transfer_fee'].std()
meanAge = data['Age'].mean()
stdAge = data['Age'].std()

dataClean = data[(np.abs((data['Transfer_fee']-meanTransferFee)/stdTransferFee) <= 3) 
                 & (np.abs((data['Age']-meanAge)/stdAge) <= 3)]

# %%
# scatter plot setelah menghilangkan outliers

import matplotlib.pyplot as plt
plt.scatter(dataClean['Age'], dataClean['Transfer_fee'])
plt.xlabel('Age')
plt.ylabel('Transfer Fee')
plt.xlim(-1, 50)
plt.ylim(-1e7, 2.5e8)
plt.show()

# %% [markdown]
# ## Latihan Project

# %% [markdown]
# - Importlah file weight-height.csv
# - Pilihlah kolom Gender, Height (dalam inch), dan Weight (dalam pound)
# - Lakukan cleaning data dengan menghilangkan data null pada kedua kolom tersebut
# - Lakukan cleaning data terhadap outlier yang ada
# - Dari data hasil cleaning, buat kolom baru 'BBI' yang isinya merupakan berat badan idealnya
#
# **Rumus BBI:**
# - wanita: (tinggi badan - 100) - (15% x (tinggi badan - 100))
# - pria: (tinggi badan - 100) - (10% x (tinggi badan -100))
#
# Keterangan untuk hitung BBI:
# - Tinggi badan dalam cm (1 inch = 2.54 cm)
# - Berat badan dalam Kg (1 pound = 0.45 kg)
